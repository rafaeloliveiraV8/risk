# %%
import pandas as pd
import numpy as np
import os
import yaml
from datetime import datetime as dt

from v8_passivo.utils import Utils
from v8_utilities.paths import PathV8
from v8_utilities.logv8 import LogV8
from v8_server.sql.sql_server import SQL_Server
from v8_utilities.anbima_calendar import Calendar
from v8_conciliacao.portfolio.everysk import Portfolio as EveryskPortfolio

# %%
from v8_risk.files.data_loader import DataLoader

ref_date = dt(2026, 2, 27)

data_loader = DataLoader(ref_date)

# %%
df = data_loader.load()

df
# Out:
# 2026-03-13 18:34:17,745 - INFO - v8_conciliacao.portfolio.everysk - __init__ - Iniciando instância
# 2026-03-13 18:34:18,541 - INFO - v8_conciliacao.portfolio.everysk - load_portfolio - Portifolio carregado para 27/02/2026
# 2026-03-13 18:34:18,545 - INFO - v8_conciliacao.portfolio.everysk - load_portfolio - Portifolio carregado com sucesso.
#       port_date   port_link_uid           port_name      port_nlv  \
# 0    2026-02-27  10462494000180      PRINCIPAL FIDC  3.083809e+08
# 1    2026-02-27  10462494000180      PRINCIPAL FIDC  3.083809e+08
# 2    2026-02-27  10462494000180      PRINCIPAL FIDC  3.083809e+08
# 3    2026-02-27  10462494000180      PRINCIPAL FIDC  3.083809e+08
# 4    2026-02-27  10462494000180      PRINCIPAL FIDC  3.083809e+08
# ...         ...             ...                 ...           ...
# 9826 2026-02-27  63712189000165  SPEEDWAY VEGA PREV  1.116620e+06
# 9827 2026-02-27  63712189000165  SPEEDWAY VEGA PREV  1.116620e+06
# 9828 2026-02-27  63712189000165  SPEEDWAY VEGA PREV  1.116620e+06
# 9829 2026-02-27  63712189000165  SPEEDWAY VEGA PREV  1.116620e+06
# 9830 2026-02-27  63712189000165  SPEEDWAY VEGA PREV  1.116620e+06
#
#      sec_attribute_ticker  sec_attribute_look_through_reference  \
# 0           REPO_20260302                        48961102000108
# 1           REPO_20260302                        39503484000127
# 2           REPO_20260302                        39503484000127
# 3          ABCB4_20261001                        39502594000174
# 4          ALLD3_20260330                        39502594000174
# ...                   ...                                   ...
# 9826    PROV:BRL_20260306                        63712189000165
# 9827    PROV:BRL_20260313                        63712189000165
# 9828    PROV:BRL_20260508                        63712189000165
# 9829    PROV:BRL_20261230                        63712189000165
# 9830             CASH:BRL                        63712189000165
#
#      sec_attribute_trade_id  sec_attribute_market_price  \
# 0                   C117937                  705.395758
# 1                   C117948                  471.354732
# 2                   C117947                  705.395758
# 3                       NaN                    0.926996
# 4                       NaN                    0.988614
# ...                     ...                         ...
# 9826                    NaN                    1.000000
# 9827                    NaN                    1.000000
# 9828                    NaN                    1.000000
# 9829                    NaN                    1.000000
# 9830                    NaN                    1.000000
#
#       sec_attribute_quantity  sec_attribute_market_value  \
# 0               9.356713e+02                6.600186e+05
# 1               1.488016e+03                7.013834e+05
# 2               6.480753e+02                4.571496e+05
# 3               1.566156e+05                1.451821e+05
# 4               8.248024e+03                8.154111e+03
# ...                      ...                         ...
# 9826           -6.267600e+02               -6.267600e+02
# 9827           -2.000000e+00               -2.000000e+00
# 9828           -8.784000e+01               -8.784000e+01
# 9829           -1.834900e+02               -1.834900e+02
# 9830           -1.365286e+06               -1.365286e+06
#
#      sec_attribute_maturity_date sec_attribute_classe sec_attribute_subclasse  \
# 0                     2026-03-02                CAIXA                   CAIXA
# 1                     2026-03-02                CAIXA                   CAIXA
# 2                     2026-03-02                CAIXA                   CAIXA
# 3                     2026-10-01           RENDA FIXA                   TERMO
# 4                     2026-03-30           RENDA FIXA                   TERMO
# ...                          ...                  ...                     ...
# 9826                         NaT               OUTROS               PROVISÕES
# 9827                         NaT               OUTROS               PROVISÕES
# 9828                         NaT               OUTROS               PROVISÕES
# 9829                         NaT               OUTROS               PROVISÕES
# 9830                         NaT                CAIXA                   CAIXA
#
#      sec_attribute_tipo
# 0         COMPROMISSADA
# 1         COMPROMISSADA
# 2         COMPROMISSADA
# 3                 TERMO
# 4                 TERMO
# ...                 ...
# 9826         TAXA CETIP
# 9827         TAXA SELIC
# 9828           TAXA CVM
# 9829          AUDITORIA
# 9830              CAIXA
#
# [9831 rows x 14 columns]
